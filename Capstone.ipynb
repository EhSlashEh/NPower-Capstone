# %% [markdown]
# Data-Driven Insights:​ Trends in Programming Languages and Databases

# %%
import matplotlib.pyplot as plt

# Data from Stack Overflow Developer Survey 2024 https://survey.stackoverflow.co/2024/technology
languages = ["JavaScript", "HTML/CSS", "Python", "SQL", "TypeScript", "Bash/Shell", "Java", "C#", "C++", "C"]
current_usage = [63.61, 52.97, 49.28, 48.66, 38.87, 32.37, 30.55, 27.62, 22.42, 19.34]

# Create vertical bar chart for current usage
plt.figure(figsize=(10, 6))
plt.bar(languages, current_usage, color='royalblue')
plt.ylabel("Usage Percentage (%)")
plt.title("Top 10 Programming Languages (2024 Survey)")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from Stack Overflow Developer Survey 2015
languages_2015 = ["JavaScript", "SQL", "Java", "C#", "PHP", "Python", "C++", "C", "Node.js", "AngularJS"]
usage_2015 = [54.4, 48.0, 37.4, 31.6, 29.7, 23.8, 20.6, 16.4, 13.3, 13.3]

# Create vertical bar chart for 2015 usage
plt.figure(figsize=(10, 6))
plt.bar(languages_2015, usage_2015, color='royalblue')
plt.ylabel("Usage Percentage (%)")
plt.title("Top 10 Programming Languages (2015 Survey)")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from Stack Overflow Developer Surveys
languages_2024 = ["JavaScript", "HTML/CSS", "Python", "SQL", "TypeScript", "Bash/Shell", "Java", "C#", "C++", "C"]
usage_2024 = [63.61, 52.97, 49.28, 48.66, 38.87, 32.37, 30.55, 27.62, 22.42, 19.34]

languages_2015 = ["JavaScript", "SQL", "Java", "C#", "PHP", "Python", "C++", "C", "Node.js", "AngularJS"]
usage_2015 = [54.4, 48.0, 37.4, 31.6, 29.7, 23.8, 20.6, 16.4, 13.3, 13.3]

# Collect all unique languages
all_languages = list(set(languages_2024 + languages_2015))

# Use the new colormap approach
color_palette = plt.colormaps["tab10"]
color_map = {lang: color_palette(i % 10) for i, lang in enumerate(all_languages)}

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Set common Y-axis limit
max_y = max(max(usage_2024), max(usage_2015))
y_limit = (0, max_y + 5)  # Add a little padding

# Plot 2024 survey data
colors_2024 = [color_map[lang] for lang in languages_2024]
axes[0].bar(languages_2024, usage_2024, color=colors_2024)
axes[0].set_title("Top 10 Programming Languages (2024)")
axes[0].set_ylabel("Usage Percentage (%)")
axes[0].set_xticklabels(languages_2024, rotation=45)
axes[0].grid(axis='y', linestyle='--', alpha=0.7)
axes[0].set_ylim(y_limit)

# Plot 2015 survey data
colors_2015 = [color_map[lang] for lang in languages_2015]
axes[1].bar(languages_2015, usage_2015, color=colors_2015)
axes[1].set_title("Top 10 Programming Languages (2015)")
axes[1].set_ylabel("Usage Percentage (%)")
axes[1].set_xticklabels(languages_2015, rotation=45)
axes[1].grid(axis='y', linestyle='--', alpha=0.7)
axes[1].set_ylim(y_limit)

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# C:\Users\antho\AppData\Local\Temp\ipykernel_4180\4259126255.py:29: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(languages_2024, rotation=45)
# C:\Users\antho\AppData\Local\Temp\ipykernel_4180\4259126255.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(languages_2015, rotation=45)

# %%
import matplotlib.pyplot as plt # type: ignore

# Data from DB-Engines Ranking :contentReference[oaicite:1]{index=1} and :contentReference[oaicite:2]{index=2}
databases = ["Oracle", "MySQL", "MS SQL Server", "PostgreSQL", "MongoDB", "Redis", "Snowflake", "Elasticsearch", "IBM Db2", "SQLite"]
current_scores = [1254.82, 999.99, 786.87, 659.62, 396.63, 157.91, 155.58, 134.63, 125.44, 113.82]

plt.figure(figsize=(10, 6))
plt.barh(databases[::-1], current_scores[::-1], color='darkorange')
plt.xlabel("Popularity Score")
plt.title("Top 10 Databases (DB-Engines Ranking)")
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Simulated projected growth percentages for databases (estimates)
growth_db = [3, 2, 1, 8, 5, 4, 15, 3, 2, 1]  # in percentage points

plt.figure(figsize=(10, 6))
plt.barh(databases[::-1], growth_db[::-1], color='purple')
plt.xlabel("Projected Growth (%)")
plt.title("Projected Growth of Databases (Next Year)")
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate sample data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)  # First graph: Sine wave
y2 = np.cos(x)  # Second graph: Cosine wave

# Create the plot
plt.figure(figsize=(8, 5))

# Plot both graphs
plt.plot(x, y1, label="Sine Wave", color="blue", linestyle="-")
plt.plot(x, y2, label="Cosine Wave", color="red", linestyle="--")

# Add labels and title
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Sine and Cosine Waves")

# Show legend
plt.legend()

# Show the plot
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 4))

ax[0].plot(x, y1, label="Sine Wave", color="blue")
ax[0].set_title("Sine Wave")
ax[0].legend()

ax[1].plot(x, y2, label="Cosine Wave", color="red")
ax[1].set_title("Cosine Wave")
ax[1].legend()

plt.tight_layout()
plt.show()
